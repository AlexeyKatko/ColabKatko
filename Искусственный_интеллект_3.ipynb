# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexeyKatko/ColabKatko/blob/main/%D0%98%D1%81%D0%BA%D1%83%D1%81%D1%81%D1%82%D0%B2%D0%B5%D0%BD%D0%BD%D1%8B%D0%B9_%D0%B8%D0%BD%D1%82%D0%B5%D0%BB%D0%BB%D0%B5%D0%BA%D1%82_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Урок 3. Создание проекта машинного обучения
#
# 1. Подумайте о реальной проблеме, которую, по вашему мнению, можно решить с помощью машинного обучения. Четко определите эту проблему и поставьте SMART-цели для ее решения. Помните, что это должна быть проблема, в которой машинное обучение может помочь сделать прогноз, классифицировать данные или дать рекомендации.
# 2. Определите потенциальные источники данных, которые могут быть использованы для решения вашей проблемы. Какие данные вам понадобятся? Где вы можете их получить? Напишите краткое резюме вашей стратегии сбора данных.
# 3. Даже если у вас нет реальных данных для анализа, представьте, что они у вас есть. Как бы вы стали исследовать и понимать эти данные? Что бы вы искали? Напишите краткое описание вашей стратегии анализа исследовательских данных.
# 4. Вспомните различные модели машинного обучения, которые мы обсуждали, в частности модель "Дерево решений". Какой тип модели машинного обучения будет наиболее подходящим для вашей проблемы и почему? Объясните свой выбор.
# Напишите краткое описание того, как вы будете обучать и оценивать выбранную вами модель машинного обучения, используя воображаемый набор данных.
#
# Наконец, подумайте о том, как вы могли бы развернуть свою обученную модель. Где она будет использоваться? Кто будет ее использовать? Какую пользу она принесет им? Напишите краткое резюме вашей стратегии развертывания.
#
# Помните, что целью этого задания является не создание реальной модели машинного обучения (пока!), а применение концепций, которые вы изучили на этом семинаре, к реальной проблеме.

# %% [markdown]
# ## Задачи

# %% [markdown]
# **Что такое машинное обучение**
#
# Благодаря созданию и развитию искусственного интеллекта (ИИ) компьютер теперь может решать множество задач: прогнозировать колебания рынка, предлагать пользователю подходящие товары и фильмы, предсказывать кибератаки и фильтровать спам. Чтобы эти задачи можно было выполнить, специалисты обучают компьютер, то есть занимаются машинным обучением.

# %% [markdown]
# **Машинное обучение (МО)** — это создание алгоритмов, с помощью которых машина может обобщить какой-либо опыт и найти для известных случаев закономерности. Например, ИИ может научиться находить аномалии на снимках КТ или МРТ и определять, здоров ли пациент. По результату МО мы получаем модель, которую можно использовать для автоматизированного или полуавтоматизированного принятия решений.

# %% [markdown]
# **Обученная модель** — это своего рода компьютерная программа, отражающая искомую закономерность. С помощью такой модели можно применять найденную зависимость к новым частным случаям.
#
# Итак, к машинному обучению прибегают, чтобы выявлять полезные закономерности. А для этого, в свою очередь, требуются алгоритмы обучения и накопленные данные об объекте наблюдения.

# %% [markdown]
# Суммируя, задача для машинного обучения всегда имеет три составляющие:
#
# - закономерность, которая существует в явном и неявном виде;
#
# - набор репрезентативных данных, внутри которых прослеживается закономерность;
#
# - алгоритмы (или модели), которые на основе данных выявляют закономерность.

# %% [markdown]
# ## Цели

# %% [markdown]
# Рассмотрим пример на данных по титанику:
#
#   Как цель, ставим ответ (закономерность) на такие вопросы как:
#
# - Сколько человек в группе пережили катастрофу с "Титаником"?
# - Количество выживших мужчин по сравнению с количеством мужчин, которые не выжили
# - Количество выживших женщин по сравнению с количеством женщин, которые не выжили
# - Играет ли возраст роль?
#
# Для этого нам понадобятся данные:

# %%
# !git clone https://github.com/AlexeyKatko/ColabKatko.git
# Out:
# Cloning into 'ColabKatko'...
# remote: Enumerating objects: 70, done.
# remote: Counting objects: 100% (70/70), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 70 (delta 31), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (70/70), 1.43 MiB | 5.17 MiB/s, done.
# Resolving deltas: 100% (31/31), done.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# Набор данных
df = '/content/ColabKatko/train'
data = pd.read_csv('/content/ColabKatko/train')

# %% [markdown]
# ## Данные

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Прежде чем приступить к выполнению поставленных задач, необходимо изучить данные, на предмет что они содержут и в каком обьеме и формате:

# %%
data.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
data.sample(5)
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 266          267         0       3       Panula, Mr. Ernesti Arvid    male
# 249          250         0       2   Carter, Rev. Ernest Courtenay    male
# 136          137         1       1    Newsom, Miss. Helen Monypeny  female
# 603          604         0       3       Torber, Mr. Ernst William    male
# 7              8         0       3  Palsson, Master. Gosta Leonard    male
#
#       Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 266  16.0      4      1  3101295  39.6875   NaN        S
# 249  54.0      1      0   244252  26.0000   NaN        S
# 136  19.0      0      2    11752  26.2833   D47        S
# 603  44.0      0      0   364511   8.0500   NaN        S
# 7     2.0      3      1   349909  21.0750   NaN        S

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Здесь мы видим что есть 891 объект (людей), 12 признаков, есть признаки с отсутствующими значениями Age, Cabin, Embarked
#
# Не целочисленные Age, Fare
#
# Целочисленные PassengerId, Survived, Pclass, SibSp, Parch
#
# Текстовые Name, Sex, Ticket
#
# Расшифруем данные столбцов:
#
# Описание переменных (названия столбцов).
# survival - выжившие: 0 = No, 1 = Yes
#
# pclass - класс билета 1 = 1st, 2 = 2nd, 3 = 3rd
#
# sex - пол
#
# Age - возраст в годах
#
# sibsp - количество родственников/супруги на борту "Титаника"
#
# parch - количество родителей / детей
#
# ticket - номер билета
#
# fare - стоимость проезда
#
# cabin - номер каюты
#
# embarked - порт посадки C = Cherbourg, Q = Queenstown, S = Southampton
#
# Примечания
#
# pclass: Показатель социально-экономического статуса (SES)
#
# 1st = высокий 2nd = средний 3rd = низкий
#
# age: Возраст является дробным, если меньше 1. Если возраст оценочный, то он имеет вид xx.5
#
# sibsp: В датасете семейные отношения определяются таким образом...
#
# Sibling = brother, sister, stepbrother, stepsister
#
# Spouse = husband, wife (mistresses and fiancés were ignored)
#
# parch: В датасете семейные отношения определяются таким образом...
#
# Parent = mother, father
#
# Child = daughter, son, stepdaughter, stepson
#
# Некоторые дети путешествовали только с няней, поэтому для них parch=0.

# %% [markdown]
# ## Проверка всех отсутствующих данных

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# ### Достижение 1 цели

# %% [markdown]
# Ответим на первую задачу - сколько выжило:

# %%
f,ax=plt.subplots(1,2,figsize=(10,5))
data['Survived'].value_counts().plot.pie(explode=[0.2,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Выжившие')
ax[0].set_ylabel('1-выжили, 0-умерли')
sns.countplot(x='Survived',data=data,ax=ax[1])
#sns.countplot(data=data,ax=ax[1])
ax[1].set_title('Выжившие')
plt.show()

# %% [markdown]
# ### Достижение 2 и 3 цели

# %% [markdown]
# Теперь ответим на 2 и 3 задачу
#
# - Количество выживших мужчин по сравнению с количеством мужчин, которые не выжили
# - Количество выживших женщин по сравнению с количеством женщин, которые не выжили

# %%
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %% [markdown]
# Отсюда видно что женщин погибло меньше чем мужчин
#
# - Мужчины : погибли 468 мужчин, выжили 109
# - Женщины : погибли 81 женщина, выжили 233
#
# отобразим наглядно:

# %%
f,ax=plt.subplots(1,2,figsize=(10,5))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Выжившие по полу')
sns.countplot(x='Sex',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Пол: выживших и мертвых')
plt.show()

# %% [markdown]
# ### Достижение 4 цели

# %% [markdown]
# Ответим на последний поставленный вопрос
#
# - Играет ли возраст роль?

# %%
print('Самый пожилой пассажир:',data['Age'].max(),'лет')
print('Самый молодой пассажир::',data['Age'].min(),'лет')
print('Средний возраст на корабле:',data['Age'].mean(),'лет')
print('Медиана возраст на корабле:',data['Age'].median(),'лет')
# Out:
# Самый пожилой пассажир: 80.0 лет
# Самый молодой пассажир:: 0.42 лет
# Средний возраст на корабле: 29.69911764705882 лет
# Медиана возраст на корабле: 28.0 лет

# %%
data['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.boxplot(x="Pclass",y="Age", hue="Survived", data=data,ax=ax[0])
ax[0].set_title('Класс и возраст в сравнении с выжившими')
ax[0].set_yticks(range(0,110,10))

sns.boxplot(x="Sex",y="Age", hue="Survived", data=data,ax=ax[1])
ax[1].set_title('Пол и возраст в сравнении с выжившими')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot(x="Pclass",y="Age", hue="Survived", data=data,split=True,ax=ax[0])
ax[0].set_title('Класс и возраст в сравнении с выжившими')
ax[0].set_yticks(range(0,110,10))
sns.violinplot(x="Sex",y="Age", hue="Survived", data=data,split=True,ax=ax[1])
ax[1].set_title('Пол и возраст в сравнении с выжившими')
ax[1].set_yticks(range(0,110,10))
plt.show()
